# %%
import pandas as pd
slist = pd.read_csv('stationlist.csv')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
import shapefile as shp
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(style="whitegrid", palette="pastel", color_codes=True)
sns.mpl.rc("figure", figsize=(10,6))

# %%
shp_path = "/Users/sadaharu/repos/psychroM/psychoM/states_21basic/states.shp"
sf = shp.Reader(shp_path)

# %%
len(sf.shapes())
# Out:
# 51

# %%
def read_shapefile(sf):
    """
    Read a shapefile into a Pandas dataframe with a 'coords' 
    column holding the geometry information. This uses the pyshp
    package
    """
    fields = [x[0] for x in sf.fields][1:]
    records = sf.records()
    shps = [s.points for s in sf.shapes()]
    df = pd.DataFrame(columns=fields, data=records)
    df = df.assign(coords=shps)
    return df

# %%
df = read_shapefile(sf)
df.shape
# Out:
# (51, 6)

# %%
def plot_map(sf, x_lim = None, y_lim = None, figsize = (13,9)):
    '''
    Plot map with lim coordinates
    '''
    plt.figure(figsize = figsize)
    id=0
    for shape in sf.shapeRecords():
        x = [i[0] for i in shape.shape.points[:]]
        y = [i[1] for i in shape.shape.points[:]]
        plt.plot(x, y, 'k')
        
        if (x_lim == None) & (y_lim == None):
            x0 = np.mean(x)
            y0 = np.mean(y)
            plt.text(x0, y0, id, fontsize=10)
        id = id+1
    
    if (x_lim != None) & (y_lim != None):     
        plt.xlim(x_lim)
        plt.ylim(y_lim)

# %%
plot_map(sf)

# %%
y_lim = (23,50) # latitude 
x_lim = (-130, -66.25) # longitude
plot_map(sf, x_lim, y_lim,figsize = (16,9))
sns.scatterplot(lon,lat)
plt.xlabel('Longtitude')
plt.ylabel('Latitude')
# Out:
# Text(0, 0.5, 'Latitude')

# %%
slist = pd.read_csv('stationlist.csv')
lat = slist.LAT.values
lon = slist.LON.values

# %%
slist
# Out:
#          USAF   WBAN                                       STATION NAME CTRY  \
# 0        7018  99999                                         WXPOD 7018  NaN
# 1        7026  99999                                         WXPOD 7026   AF
# 2        7070  99999                                         WXPOD 7070   AF
# 3        8260  99999                                          WXPOD8270  NaN
# 4        8268  99999                                          WXPOD8278   AF
# 5        8307  99999                                         WXPOD 8318   AF
# 6        8411  99999                                               XM20  NaN
# 7        8414  99999                                               XM18  NaN
# 8        8415  99999                                               XM21  NaN
# 9        8418  99999                                               XM24  NaN
# 10      10000  99999                                       BOGUS NORWAY   NO
# ...

# %%
slist.columns
# Out:
# Index(['USAF', 'WBAN', 'STATION NAME', 'CTRY', 'STATE', 'ICAO', 'LAT', 'LON',
#        'ELEV(M)', 'BEGIN', 'END'],
#       dtype='object')

# %%
slist.describe()
# Out:
#                WBAN           LAT           LON       ELEV(M)         BEGIN  \
# count  29820.000000  28611.000000  28610.000000  28517.000000  2.982000e+04
# mean   90029.586184     30.714452     -3.527815    342.676796  1.978379e+07
# std    27229.809644     28.765004     87.301368    590.203344  2.354413e+05
# min        1.000000    -90.000000   -179.983000   -999.900000  1.901010e+07
# 25%    99999.000000     21.026000    -82.838750     20.700000  1.959010e+07
# 50%    99999.000000     38.966000      5.415000    135.000000  1.977021e+07
# 75%    99999.000000     49.741500     59.346000    428.000000  2.001092e+07
# max    99999.000000     89.370000    179.750000   8318.000000  2.018100e+07
#
#                 END
# count  2.982000e+04
# mean   2.004721e+07
# std    1.904915e+05
# min    1.905123e+07
# 25%    2.001090e+07
# 50%    2.015033e+07
# 75%    2.018101e+07
# max    2.018101e+07

# %%
fig = plt.figure(figsize=(8,8))
m=
